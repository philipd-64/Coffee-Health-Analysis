# %% [markdown]
# # Import

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(font_scale=0.8)
import matplotlib
import matplotlib.pyplot as plt
import scipy

# %%
path = r'C:\Users\rubix\Downloads\Achievement 6'
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Coffee_Wrangled.csv'), index_col = False)

# %%
df
# Out:
#       Unnamed: 0  Age  Gender  Country  Coffee_Intake  Caffeine_mg  \
# 0              0   40    Male  Germany            3.5        328.1
# 1              1   33    Male  Germany            1.0         94.1
# 2              2   42    Male   Brazil            5.3        503.7
# 3              3   53    Male  Germany            2.6        249.2
# 4              4   32  Female    Spain            3.1        298.0
# ...          ...  ...     ...      ...            ...          ...
# 9995        9995   50  Female    Japan            2.1        199.8
# 9996        9996   18  Female       UK            3.4        319.2
# 9997        9997   26    Male    China            1.6        153.4
# 9998        9998   40  Female  Finland            3.4        327.1
# 9999        9999   42  Female   Brazil            2.9        277.5
#
#       Sleep_Hours Sleep_Quality   BMI  Heart_Rate Stress_Level  \
# 0             7.5          Good  24.9          78          Low
# ...

# %%
plt.rcParams["figure.dpi"] = 300 # Default DPI

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df
# Out:
#       Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 0      40    Male  Germany            3.5        328.1          7.5
# 1      33    Male  Germany            1.0         94.1          6.2
# 2      42    Male   Brazil            5.3        503.7          5.9
# 3      53    Male  Germany            2.6        249.2          7.3
# 4      32  Female    Spain            3.1        298.0          5.3
# ...   ...     ...      ...            ...          ...          ...
# 9995   50  Female    Japan            2.1        199.8          6.0
# 9996   18  Female       UK            3.4        319.2          5.8
# 9997   26    Male    China            1.6        153.4          7.1
# 9998   40  Female  Finland            3.4        327.1          7.0
# 9999   42  Female   Brazil            2.9        277.5          6.4
#
#      Sleep_Quality   BMI  Heart_Rate Stress_Level  Physical_Activity_Hours  \
# ...

# %% [markdown]
# # Sleep Quality

# %%
df['Sleep_Quality'].value_counts()
# Out:
# Sleep_Quality
# Good         5637
# Fair         2050
# Excellent    1352
# Poor          961
# Name: count, dtype: int64

# %%
df['Sleep_Quality'].replace('Poor', '1')
# Out:
# 0       Good
# 1       Good
# 2       Fair
# 3       Good
# 4       Fair
#         ...
# 9995    Fair
# 9996    Fair
# 9997    Good
# 9998    Good
# 9999    Good
# Name: Sleep_Quality, Length: 10000, dtype: object

# %%
df['Sleep_Quality'] = df['Sleep_Quality'].replace('Poor', 1)

# %%
df['Sleep_Quality'] = df['Sleep_Quality'].replace('Fair', 2)

# %%
df['Sleep_Quality'] = df['Sleep_Quality'].replace('Good', 3)

# %%
df['Sleep_Quality'] = df['Sleep_Quality'].replace('Excellent', 4)
# Out:
# C:\Users\rubix\AppData\Local\Temp\ipykernel_35300\3310709535.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sleep_Quality'] = df['Sleep_Quality'].replace('Excellent', 4)

# %%
df['Sleep_Quality'].value_counts()
# Out:
# Sleep_Quality
# 3    5637
# 2    2050
# 4    1352
# 1     961
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Age                          int64
# Gender                      object
# Country                     object
# Coffee_Intake              float64
# Caffeine_mg                float64
# Sleep_Hours                float64
# Sleep_Quality                int64
# BMI                        float64
# Heart_Rate                   int64
# Stress_Level                object
# Physical_Activity_Hours    float64
# Health_Issues               object
# Occupation                  object
# Smoking                       bool
# Alcohol_Consumption           bool
# Resting_Heart_Rate          object
# dtype: object

# %% [markdown]
# # Stress Level

# %%
df['Stress_Level'].value_counts()
# Out:
# Stress_Level
# Low       6989
# Medium    2050
# High       961
# Name: count, dtype: int64

# %%
df['Stress_Level'] = df['Stress_Level'].replace('Low', 1)
df['Stress_Level'] = df['Stress_Level'].replace('Medium', 2)
df['Stress_Level'] = df['Stress_Level'].replace('High', 3)
# Out:
# C:\Users\rubix\AppData\Local\Temp\ipykernel_35300\4040526743.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Stress_Level'] = df['Stress_Level'].replace('High', 3)

# %%
df.dtypes
# Out:
# Age                          int64
# Gender                      object
# Country                     object
# Coffee_Intake              float64
# Caffeine_mg                float64
# Sleep_Hours                float64
# Sleep_Quality                int64
# BMI                        float64
# Heart_Rate                   int64
# Stress_Level                 int64
# Physical_Activity_Hours    float64
# Health_Issues               object
# Occupation                  object
# Smoking                       bool
# Alcohol_Consumption           bool
# Resting_Heart_Rate          object
# dtype: object

# %% [markdown]
# # Health Issues

# %%
df['Health_Issues'].value_counts()
# Out:
# Health_Issues
# Zero        5941
# Mild        3579
# Moderate     463
# Severe        17
# Name: count, dtype: int64

# %%
df['Health_Issues'] = df['Health_Issues'].replace('Zero', 1)
df['Health_Issues'] = df['Health_Issues'].replace('Mild', 2)
df['Health_Issues'] = df['Health_Issues'].replace('Moderate', 3)
df['Health_Issues'] = df['Health_Issues'].replace('Severe', 4)
# Out:
# C:\Users\rubix\AppData\Local\Temp\ipykernel_35300\1609912963.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Health_Issues'] = df['Health_Issues'].replace('Severe', 4)

# %%
df['Health_Issues'].value_counts()
# Out:
# Health_Issues
# 1    5941
# 2    3579
# 3     463
# 4      17
# Name: count, dtype: int64

# %%
df
# Out:
#       Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 0      40    Male  Germany            3.5        328.1          7.5
# 1      33    Male  Germany            1.0         94.1          6.2
# 2      42    Male   Brazil            5.3        503.7          5.9
# 3      53    Male  Germany            2.6        249.2          7.3
# 4      32  Female    Spain            3.1        298.0          5.3
# ...   ...     ...      ...            ...          ...          ...
# 9995   50  Female    Japan            2.1        199.8          6.0
# 9996   18  Female       UK            3.4        319.2          5.8
# 9997   26    Male    China            1.6        153.4          7.1
# 9998   40  Female  Finland            3.4        327.1          7.0
# 9999   42  Female   Brazil            2.9        277.5          6.4
#
#       Sleep_Quality   BMI  Heart_Rate  Stress_Level  Physical_Activity_Hours  \
# ...

# %% [markdown]
# # Export New .csv

# %%
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Coffee_Numerical_Wrangled.csv'))

# %% [markdown]
# # Heatmap

# %%
heat_df = df.corr(numeric_only=True)

# %%
updated_heat = sns.heatmap(heat_df, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.1, font_scale=0.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 updated_heat = sns.heatmap(heat_df, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.1, font_scale=0.8)
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
#     305 # Draw the heatmap
# --> 306 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     308 # Set the axis limits
# ...

# %%
updated_heat.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'Updated_Heatmap.png'), bbox_inches='tight')
